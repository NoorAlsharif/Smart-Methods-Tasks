# %% [markdown]
# ## 0. Install and Import Dependencies

# %%
# !pip install ibm_watson

# %%
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource 
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# ## 1. Setup STT Service

# %%
apikey = 'SS-unJatJFW2fCYMJdr2j74oGHquiDK6n6RChm4xEDGA'
url = 'https://api.us-east.speech-to-text.watson.cloud.ibm.com/instances/3fa3011a-77c0-460a-8ace-026aee2395d9'

# %%
# Setup Service
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)

# %% [markdown]
# ## 2. Open Audio Source and Convert

# %%
# Perform conversion
with open('Hello.mp3', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/mp3', model='en-US_NarrowbandModel', continuous=True).get_result()

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': 'hello ', 'confidence': 0.9}]}]}

# %%
text = res['results'][0]['alternatives'][0]['transcript']
text
# Out:
# 'hello '

# %%
confidence = res['results'][0]['alternatives'][0]['confidence']
confidence
# Out:
# 0.9

# %%
with open('output.txt', 'w') as out:
    out.writelines(text)
